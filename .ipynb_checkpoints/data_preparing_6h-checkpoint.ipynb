# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('saved_dataframe/df_pure_19_12_20.csv')

# %%
input = 1592671756 + 60 * 60
df.iloc[(df['UnixTime'] - input).abs().argsort()[:10]]
# Out:
#      Humidity  Temperature    UnixTime  Hour  Minute
# 625      66.0         32.9  1592674430    17      33
# 624      65.0         32.9  1592674419    17      33
# 623      65.0         32.9  1592674408    17      33
# 622      65.0         32.9  1592674397    17      33
# 621      65.0         32.9  1592674387    17      33
# 620      66.0         32.9  1592674377    17      32
# 619      66.0         32.9  1592674366    17      32
# 618      66.0         32.9  1592674356    17      32
# 626      76.0         32.4  1592676363    18       6
# 617      66.0         32.9  1592674345    17      32

# %%
df_future = pd.DataFrame(columns = ['Humidity', 'Temperature', 'UnixTime', 'Hour', 'Minute', 
                                          'Humidity_Future', 'Temperature_Future', 'UnixTime_Future', 'Hour_Future', 'Minute_Future'])

# %%
threshold = 60 * 60 * 6

for i, j in df.iterrows():
    input = j['UnixTime'] + threshold
    feature = df.iloc[(df['UnixTime'] - input).abs().argsort()[:2]]
    selected = feature.iloc[0]
    
    if selected['UnixTime'] == j['UnixTime']:
        break
    
    if abs(selected['UnixTime'] - j['UnixTime'] - threshold) > abs(feature.iloc[1]['UnixTime'] - j['UnixTime'] - threshold):
        selected = feature.iloc[1]
        
    df_future = df_future.append({'Humidity' : j['Humidity'], 
                    'Temperature' : j['Temperature'], 
                    'UnixTime' : j['UnixTime'], 
                    'Hour' : j['Hour'], 
                    'Minute' : j['Minute'], 
                    'Humidity_Future' : selected['Humidity'], 
                    'Temperature_Future' : selected['Temperature'], 
                    'UnixTime_Future' : selected['UnixTime'], 
                    'Hour_Future' : selected['Hour'], 
                    'Minute_Future' : selected['Minute']},  
                   ignore_index = True)
    if i % 1000 == 0:
        print(i)
        
print('done')
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# done

# %%
pd.set_option('display.float_format', lambda x: '%.10f' % x)
# pd.reset_option('display.float_format')

# %%
df_future.head()
# Out:
#        Humidity   Temperature              UnixTime          Hour  \
# 0 72.0000000000 34.6000000000 1592667750.0000000000 15.0000000000
# 1 66.0000000000 34.6000000000 1592667761.0000000000 15.0000000000
# 2 66.0000000000 34.6000000000 1592667774.0000000000 15.0000000000
# 3 66.0000000000 34.6000000000 1592667784.0000000000 15.0000000000
# 4 66.0000000000 34.6000000000 1592667794.0000000000 15.0000000000
#
#          Minute  Humidity_Future  Temperature_Future       UnixTime_Future  \
# 0 42.0000000000    80.0000000000       30.3000000000 1592689346.0000000000
# 1 42.0000000000    80.0000000000       29.9000000000 1592689366.0000000000
# 2 42.0000000000    81.0000000000       29.9000000000 1592689377.0000000000
# 3 43.0000000000    81.0000000000       29.9000000000 1592689387.0000000000
# 4 43.0000000000    81.0000000000       29.9000000000 1592689397.0000000000
#
#     Hour_Future  Minute_Future
# 0 21.0000000000  42.0000000000
# 1 21.0000000000  42.0000000000
# 2 21.0000000000  42.0000000000
# 3 21.0000000000  43.0000000000
# 4 21.0000000000  43.0000000000

# %%
df_future.loc[377]
# Out:
# Humidity                     65.0000000000
# Temperature                  33.5000000000
# UnixTime             1592671756.0000000000
# Hour                         16.0000000000
# Minute                       49.0000000000
# Humidity_Future              89.0000000000
# Temperature_Future           27.8000000000
# UnixTime_Future      1592693351.0000000000
# Hour_Future                  22.0000000000
# Minute_Future                49.0000000000
# Name: 377, dtype: float64

# %%
verify_time = []
for i, j in df_future.iterrows():
    time_dist = abs(j['UnixTime_Future'] - j['UnixTime'] - 60 * 60 * 6) 
    verify_time.append(time_dist)
    if i % 1000 == 0:
        print(i)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 12000

# %%
np.max(verify_time)
n, bins, patches = plt.hist(verify_time)
plt.show()

# %%
print(n)
print(bins)
print(patches)
# Out:
# [12271.   358.   277.   102.    68.    51.    66.    50.    35.    45.]
# [   0.  359.  718. 1077. 1436. 1795. 2154. 2513. 2872. 3231. 3590.]
# <a list of 10 Patch objects>

# %%
for i, j in df_future.iterrows():
    if abs(j['UnixTime_Future'] - j['UnixTime'] - 60 * 60 * 6) >= 900:
        df_future.drop(index = i, inplace = True)

# %%
df_future.reset_index(drop=True, inplace=True)
df_future
# Out:
#            Humidity   Temperature              UnixTime          Hour  \
# 0     72.0000000000 34.6000000000 1592667750.0000000000 15.0000000000
# 1     66.0000000000 34.6000000000 1592667761.0000000000 15.0000000000
# 2     66.0000000000 34.6000000000 1592667774.0000000000 15.0000000000
# 3     66.0000000000 34.6000000000 1592667784.0000000000 15.0000000000
# 4     66.0000000000 34.6000000000 1592667794.0000000000 15.0000000000
# ...             ...           ...                   ...           ...
# 11401 71.0000000000 33.9000000000 1592808059.0000000000  6.0000000000
# 11402 72.0000000000 34.2000000000 1592808069.0000000000  6.0000000000
# 11403 70.0000000000 34.3000000000 1592808080.0000000000  6.0000000000
# 11404 69.0000000000 34.8000000000 1592808090.0000000000  6.0000000000
# 11405 69.0000000000 34.9000000000 1592808100.0000000000  6.0000000000
#
#              Minute  Humidity_Future  Temperature_Future  \
# 0     42.0000000000    80.0000000000       30.3000000000
# 1     42.0000000000    80.0000000000       29.9000000000
# 2     42.0000000000    81.0000000000       29.9000000000
# 3     43.0000000000    81.0000000000       29.9000000000
# 4     43.0000000000    81.0000000000       29.9000000000
# ...             ...              ...                 ...
# 11401 40.0000000000    62.0000000000       34.6000000000
# 11402 41.0000000000    62.0000000000       34.6000000000
# 11403 41.0000000000    62.0000000000       34.6000000000
# 11404 41.0000000000    62.0000000000       34.6000000000
# 11405 41.0000000000    63.0000000000       34.6000000000
#
#             UnixTime_Future   Hour_Future  Minute_Future
# 0     1592689346.0000000000 21.0000000000  42.0000000000
# 1     1592689366.0000000000 21.0000000000  42.0000000000
# 2     1592689377.0000000000 21.0000000000  42.0000000000
# 3     1592689387.0000000000 21.0000000000  43.0000000000
# 4     1592689397.0000000000 21.0000000000  43.0000000000
# ...                     ...           ...            ...
# 11401 1592829659.0000000000 12.0000000000  40.0000000000
# 11402 1592829669.0000000000 12.0000000000  41.0000000000
# 11403 1592829680.0000000000 12.0000000000  41.0000000000
# 11404 1592829690.0000000000 12.0000000000  41.0000000000
# 11405 1592829700.0000000000 12.0000000000  41.0000000000
#
# [11406 rows x 10 columns]

# %%
df_future.to_csv(r'saved_dataframe/df_with_6h_future_raw_23_12_20.csv', index=False, header=True)

# %%
df_future.drop(df_future.columns[2], axis=1, inplace=True)
df_future.drop(df_future.columns[6], axis=1, inplace=True)
df_future
# Out:
#            Humidity   Temperature          Hour        Minute  \
# 0     72.0000000000 34.6000000000 15.0000000000 42.0000000000
# 1     66.0000000000 34.6000000000 15.0000000000 42.0000000000
# 2     66.0000000000 34.6000000000 15.0000000000 42.0000000000
# 3     66.0000000000 34.6000000000 15.0000000000 43.0000000000
# 4     66.0000000000 34.6000000000 15.0000000000 43.0000000000
# ...             ...           ...           ...           ...
# 11401 71.0000000000 33.9000000000  6.0000000000 40.0000000000
# 11402 72.0000000000 34.2000000000  6.0000000000 41.0000000000
# 11403 70.0000000000 34.3000000000  6.0000000000 41.0000000000
# 11404 69.0000000000 34.8000000000  6.0000000000 41.0000000000
# 11405 69.0000000000 34.9000000000  6.0000000000 41.0000000000
#
#        Humidity_Future  Temperature_Future   Hour_Future  Minute_Future
# 0        80.0000000000       30.3000000000 21.0000000000  42.0000000000
# 1        80.0000000000       29.9000000000 21.0000000000  42.0000000000
# 2        81.0000000000       29.9000000000 21.0000000000  42.0000000000
# 3        81.0000000000       29.9000000000 21.0000000000  43.0000000000
# 4        81.0000000000       29.9000000000 21.0000000000  43.0000000000
# ...                ...                 ...           ...            ...
# 11401    62.0000000000       34.6000000000 12.0000000000  40.0000000000
# 11402    62.0000000000       34.6000000000 12.0000000000  41.0000000000
# 11403    62.0000000000       34.6000000000 12.0000000000  41.0000000000
# 11404    62.0000000000       34.6000000000 12.0000000000  41.0000000000
# 11405    63.0000000000       34.6000000000 12.0000000000  41.0000000000
#
# [11406 rows x 8 columns]

# %%
df_future.to_csv(r'saved_dataframe/df_with_6h_future_ready_to_train_23_12_20.csv', index=False, header=True)
