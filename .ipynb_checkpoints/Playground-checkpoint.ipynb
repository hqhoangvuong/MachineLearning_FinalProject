# %%
import pandas as pd
import numpy as np
from firebase import firebase
import time
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('saved_dataframe/df_pure_19_12_20.csv')
df
# Out:
#        Humidity  Temperature    UnixTime  Hour  Minute
# 0          72.0         34.6  1592667750    15      42
# 1          66.0         34.6  1592667761    15      42
# 2          66.0         34.6  1592667774    15      42
# 3          66.0         34.6  1592667784    15      43
# 4          66.0         34.6  1592667794    15      43
# ...         ...          ...         ...   ...     ...
# 14325      57.0         28.5  1594212012    12      40
# 14326      58.0         28.5  1594212022    12      40
# 14327      58.0         28.5  1594212033    12      40
# 14328      58.0         28.5  1594212043    12      40
# 14329      58.0         28.5  1594212054    12      40
#
# [14330 rows x 5 columns]

# %%
input = 1594212054 + 60
df.iloc[(df['UnixTime'] - input).abs().argsort()[:1]]
# Out:
#        Humidity  Temperature    UnixTime  Hour  Minute
# 14329      58.0         28.5  1594212054    12      40

# %%
df_future = df = pd.DataFrame(columns = ['Humidity', 'Temperature', 'UnixTime', 'Hour', 'Minute', 
                                          'Humidity_Future', 'Temperature_Future', 'UnixTime_Future', 'Hour_Future', 'Minute_Future'])
print(df_future)
# Out:
# Empty DataFrame
# Columns: [Humidity, Temperature, UnixTime, Hour, Minute, Humidity_Future, Temperature_Future, UnixTime_Future, Hour_Future, Minute_Future]
# Index: []

# %%
threshold = 60 * 60

for i, j in df.iterrows():
    input = j['UnixTime'] + threshold
    feature = df.iloc[(df['UnixTime'] - input).abs().argsort()[:2]]
    selected = feature.iloc[0]
    
    if abs(selected['UnixTime'] - j['UnixTime'] - input) > abs(feature.iloc[1]['UnixTime'] - j['UnixTime'] - input):
        selected = feature.iloc[1]
    
    if  selected['UnixTime'] == j['UnixTime']:
        break
        
    df_future = df_future.append({'Humidity' : j['Humidity'], 
                    'Temperature' : j['Temperature'], 
                    'UnixTime' : j['UnixTime'], 
                    'Hour' : j['Hour'], 
                    'Minute' : j['Minute'], 
                    'Humidity_Future' : selected['Humidity'], 
                    'Temperature_Future' : selected['Temperature'], 
                    'UnixTime_Future' : selected['UnixTime'], 
                    'Hour_Future' : selected['Hour'], 
                    'Minute_Future' : selected['Minute']},  
                   ignore_index = True) 
    print(i)

# %%
pd.set_option('display.float_format', lambda x: '%.10f' % x)

# %%
df_future
# Out:
#           Humidity   Temperature              UnixTime          Hour  \
# 0    72.0000000000 34.6000000000 1592667750.0000000000 15.0000000000
# 1    66.0000000000 34.6000000000 1592667761.0000000000 15.0000000000
# 2    66.0000000000 34.6000000000 1592667774.0000000000 15.0000000000
# 3    66.0000000000 34.6000000000 1592667784.0000000000 15.0000000000
# 4    66.0000000000 34.6000000000 1592667794.0000000000 15.0000000000
# ...            ...           ...                   ...           ...
# 5410 64.0000000000 34.6000000000 1592736772.0000000000 10.0000000000
# 5411 64.0000000000 34.6000000000 1592736782.0000000000 10.0000000000
# 5412 64.0000000000 34.7000000000 1592736793.0000000000 10.0000000000
# 5413 63.0000000000 34.8000000000 1592736813.0000000000 10.0000000000
# 5414 64.0000000000 34.8000000000 1592736824.0000000000 10.0000000000
#
#             Minute  Humidity_Future  Temperature_Future       UnixTime_Future  \
# 0    42.0000000000    66.0000000000       33.5000000000 1592671351.0000000000
# 1    42.0000000000    66.0000000000       33.5000000000 1592671362.0000000000
# 2    42.0000000000    66.0000000000       33.5000000000 1592671372.0000000000
# 3    43.0000000000    66.0000000000       33.5000000000 1592671382.0000000000
# 4    43.0000000000    66.0000000000       33.5000000000 1592671393.0000000000
# ...            ...              ...                 ...                   ...
# 5410 52.0000000000    61.0000000000       34.8000000000 1592741059.0000000000
# 5411 53.0000000000    61.0000000000       34.8000000000 1592741059.0000000000
# 5412 53.0000000000    61.0000000000       34.8000000000 1592741059.0000000000
# 5413 53.0000000000    61.0000000000       34.8000000000 1592741059.0000000000
# 5414 53.0000000000    61.0000000000       34.8000000000 1592741059.0000000000
#
#        Hour_Future  Minute_Future
# 0    16.0000000000  42.0000000000
# 1    16.0000000000  42.0000000000
# 2    16.0000000000  42.0000000000
# 3    16.0000000000  43.0000000000
# 4    16.0000000000  43.0000000000
# ...            ...            ...
# 5410 12.0000000000   4.0000000000
# 5411 12.0000000000   4.0000000000
# 5412 12.0000000000   4.0000000000
# 5413 12.0000000000   4.0000000000
# 5414 12.0000000000   4.0000000000
#
# [5415 rows x 10 columns]
