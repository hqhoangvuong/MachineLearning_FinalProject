# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('saved_dataframe/df_with_1h_future_ready_to_train_21_12_20.csv')
print(df)
# Out:
#        Humidity  Temperature  Hour  Minute  Humidity_Future  \
# 0          72.0         34.6  15.0    42.0             66.0
# 1          66.0         34.6  15.0    42.0             66.0
# 2          66.0         34.6  15.0    42.0             66.0
# 3          66.0         34.6  15.0    43.0             66.0
# 4          66.0         34.6  15.0    43.0             66.0
# ...         ...          ...   ...     ...              ...
# 11916      62.0         34.6  12.0    52.0             60.0
# 11917      62.0         34.6  12.0    53.0             60.0
# 11918      62.0         34.6  12.0    53.0             60.0
# 11919      62.0         34.6  12.0    53.0             60.0
# 11920      62.0         34.6  12.0    53.0             60.0
#
#        Temperature_Future  Hour_Future  Minute_Future
# 0                    33.5         16.0           42.0
# 1                    33.5         16.0           42.0
# 2                    33.5         16.0           42.0
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_scaler = scaler.fit_transform(df[df.columns])

# %%
df_scaler = pd.DataFrame(df_scaler, columns = df.columns)

# %%
df_scaler
# Out:
#        Humidity  Temperature      Hour    Minute  Humidity_Future  \
# 0     -0.853818     2.055793  0.368360  0.772216        -1.541922
# 1     -1.492040     2.055793  0.368360  0.772216        -1.541922
# 2     -1.492040     2.055793  0.368360  0.772216        -1.541922
# 3     -1.492040     2.055793  0.368360  0.830683        -1.541922
# 4     -1.492040     2.055793  0.368360  0.830683        -1.541922
# ...         ...          ...       ...       ...              ...
# 11916 -1.917522     2.055793 -0.015611  1.356886        -2.182488
# 11917 -1.917522     2.055793 -0.015611  1.415353        -2.182488
# 11918 -1.917522     2.055793 -0.015611  1.415353        -2.182488
# 11919 -1.917522     2.055793 -0.015611  1.415353        -2.182488
# 11920 -1.917522     2.055793 -0.015611  1.415353        -2.182488
#
#        Temperature_Future  Hour_Future  Minute_Future
# 0                1.705593     0.541949       0.772132
# 1                1.705593     0.541949       0.772132
# ...

# %%
X = df[['Humidity', 'Temperature', 'Hour', 'Minute']]
y = df['Temperature_Future']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.score(X_test, y_test)
# Out:
# 0.7215171814975577
